# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# Getting or importing the data
music_data = pd.read_csv('music.csv')

# Cleaning the data
X = music_data.drop(columns=['genre'])
y = music_data['genre']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Build a Model
# Decision Tree algorithm
model = DecisionTreeClassifier()
model.fit(X_train, y_train)

# Make Predictions
predictions = model.predict(X_test)
# music_data

# # Measure the Accuracy of the Models
# score = accuracy_score(y_test, predictions)
# score
X_train
# Out:
#     age  gender
# 7    33       1
# 17   35       0
# 14   30       0
# 16   34       0
# 9    20       0
# 6    31       1
# 2    25       1
# 15   31       0
# 10   21       0
# 1    23       1
# 8    37       1
# 4    29       1
# 11   25       0
# 5    30       1

# %%
type(X_train)
# Out:
# pandas.core.frame.DataFrame

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
import joblib

music_data = pd.read_csv('music.csv')
music_data
# Out:
#     age  gender      genre
# 0    20       1     HipHop
# 1    23       1     HipHop
# 2    25       1     HipHop
# 3    26       1       Jazz
# 4    29       1       Jazz
# 5    30       1       Jazz
# 6    31       1  Classical
# 7    33       1  Classical
# 8    37       1  Classical
# 9    20       0      Dance
# 10   21       0      Dance
# 11   25       0      Dance
# 12   26       0   Acoustic
# 13   27       0   Acoustic
# 14   30       0   Acoustic
# 15   31       0  Classical
# 16   34       0  Classical
# 17   35       0  Classical

# %%
# music_data = pd.read_csv('music.csv')
# X = music_data.drop(columns=['genre'])
# y = music_data['genre']

# model = DecisionTreeClassifier()
# model.fit(X,y)

model = joblib.load('music-recommender.joblib')
predictions = model.predict(X_test)
predictions
# Out:
# array(['Acoustic', 'Dance', 'Dance', 'Classical'], dtype=object)

# %%
import os
import shutil
current_dir = os.getcwd()
file = 'Trial Game.ipynb'
destination = os.path.join(current_dir, 'Dataset\\')

shutil.move(joinpath, current_dir)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[13], line 7
#       5 destination = os.path.join(current_dir, 'Dataset\\', file)
#       6 # joinpath = os.path.join(current_dir)
# ----> 7 shutil.move(joinpath, current_dir)
#       8 print(current_dir)
#
# File ~\.conda\envs\tf-new\lib\shutil.py:806, in move(src, dst, copy_function)
#     802 if os.path.isdir(dst):
#     803     if _samefile(src, dst):
#     804         # We might be on a case insensitive filesystem,
#     805         # perform the rename anyway.
# --> 806         os.rename(src, dst)
#     807         return
#     809     # Using _basename instead of os.path.basename is important, as we must
#     810     # ignore any trailing slash to avoid the basename returning ''
#
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\johnp\\OneDrive\\Desktop\\3rd Year\\Machine Learning' -> 'C:\\Users\\johnp\\OneDrive\\Desktop\\3rd Year\\Machine Learning'
